# %%
import requests

# %%
apiEndPoints = {
    "album": r"https://api.deezer.com/album/{0}",
    "artist": r"https://api.deezer.com/artist/{0}",
    "track": r"https://api.deezer.com/track/{0}"    
}

# %%
access_token = "frBx6ZdRjE553f9dc2a3cc9P7JptufC553f9dc2a3d00hX24wk"

# %%
def get_item_from_api(itemType, itemId):
    r = requests.get(url = apiEndPoints[itemType].format(itemId))
    return r.json()

# %%
get_item_from_api("artist", 27)
# Out:
# {'id': 27,
#  'link': 'https://www.deezer.com/artist/27',
#  'name': 'Daft Punk',
#  'nb_album': 30,
#  'nb_fan': 3025968,
#  'picture': 'https://api.deezer.com/artist/27/image',
#  'picture_big': 'https://cdns-images.dzcdn.net/images/artist/f2bc007e9133c946ac3c3907ddc5d2ea/500x500-000000-80-0-0.jpg',
#  'picture_medium': 'https://cdns-images.dzcdn.net/images/artist/f2bc007e9133c946ac3c3907ddc5d2ea/250x250-000000-80-0-0.jpg',
#  'picture_small': 'https://cdns-images.dzcdn.net/images/artist/f2bc007e9133c946ac3c3907ddc5d2ea/56x56-000000-80-0-0.jpg',
#  'radio': True,
#  'share': 'http://www.deezer.com/artist/27?utm_source=deezer&utm_content=artist-27&utm_term=0_1454754910&utm_medium=web',
#  'tracklist': 'https://api.deezer.com/artist/27/top?limit=50',
#  'type': 'artist'}

# %%
def get_history(processingFunction = process_history, length = 50):
    output = []
    increment = 50
    numberOfSteps = length // increment
    for step in range(numberOfSteps):
        url = r"http://api.deezer.com/user/me/history?access_token={0}&index={1}&limit={2}".format(access_token,step*increment, increment)
        raw = requests.get(url = url).json()
        output.extend(processingFunction(raw))
    return output

# %%
get_history()
# Out:
# [Listen(song_name="Why'd You Only Call Me When You're High?", song_id=70322139, album_name='AM', artist_name='Arctic Monkeys', timestamp=1454760192),
#  Listen(song_name='Fireside', song_id=70322138, album_name='AM', artist_name='Arctic Monkeys', timestamp=1454760031),
#  Listen(song_name='Mad Sounds', song_id=70322137, album_name='AM', artist_name='Arctic Monkeys', timestamp=1454759850),
#  Listen(song_name='No. 1 Party Anthem', song_id=70322136, album_name='AM', artist_name='Arctic Monkeys', timestamp=1454759634),
#  Listen(song_name='I Want It All', song_id=70322135, album_name='AM', artist_name='Arctic Monkeys', timestamp=1454759391),
#  Listen(song_name='Arabella', song_id=70322134, album_name='AM', artist_name='Arctic Monkeys', timestamp=1454759206),
#  Listen(song_name='One For The Road', song_id=70322133, album_name='AM', artist_name='Arctic Monkeys', timestamp=1454758999),
#  Listen(song_name='Young Folks', song_id=4194903, album_name="Writer's Block", artist_name='Peter Bjorn and John', timestamp=1454758792),
#  Listen(song_name='Best Day Of My Life', song_id=75711295, album_name='Oh, What A Life', artist_name='American Authors', timestamp=1454758621),
#  Listen(song_name='Lyla', song_id=74173060, album_name='Time Flies... 1994-2009', artist_name='Oasis', timestamp=1454758426),
#  Listen(song_name='Songbird', song_id=74173050, album_name='Time Flies... 1994-2009', artist_name='Oasis', timestamp=1454758275),
#  Listen(song_name='Songbird (2004 Remastered Edition)', song_id=67549266, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454758145),
#  Listen(song_name='Never Going Back Again (2004 Remastered Edition)', song_id=67549263, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454758080),
#  Listen(song_name='Second Hand News (2004 Remastered Edition)', song_id=67549261, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454757946),
#  Listen(song_name="Don't Stop (2004 Remastered Edition)", song_id=67549264, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454757770),
#  Listen(song_name='Little Lies', song_id=4094757, album_name='Tango In The Night', artist_name='Fleetwood Mac', timestamp=1454757576),
#  Listen(song_name='Dreams (Remastered)', song_id=63480987, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454757358),
#  Listen(song_name='Everywhere', song_id=4094753, album_name='Tango In The Night', artist_name='Fleetwood Mac', timestamp=1454757102),
#  Listen(song_name='Explorers', song_id=60946213, album_name='The 2nd Law', artist_name='Muse', timestamp=1454756857),
#  Listen(song_name='Reapers', song_id=101215850, album_name='Drones', artist_name='Muse', timestamp=1454756360),
#  Listen(song_name='Mercy', song_id=101215848, album_name='Drones', artist_name='Muse', timestamp=1454756269),
#  Listen(song_name='The Globalist', song_id=101215862, album_name='Drones', artist_name='Muse', timestamp=1454756037),
#  Listen(song_name='Aftermath', song_id=101215860, album_name='Drones', artist_name='Muse', timestamp=1454755646),
#  Listen(song_name='Revolt', song_id=101215858, album_name='Drones', artist_name='Muse', timestamp=1454755298),
#  Listen(song_name='Defector', song_id=101215856, album_name='Drones', artist_name='Muse', timestamp=1454755052),
#  Listen(song_name='[JFK]', song_id=101215854, album_name='Drones', artist_name='Muse', timestamp=1454754779),
#  Listen(song_name='The Handler', song_id=101215852, album_name='Drones', artist_name='Muse', timestamp=1454754724),
#  Listen(song_name='Reapers', song_id=101215850, album_name='Drones', artist_name='Muse', timestamp=1454754450),
#  Listen(song_name='Mercy', song_id=101215848, album_name='Drones', artist_name='Muse', timestamp=1454754092),
#  Listen(song_name='Just', song_id=3140486, album_name='The Best Of', artist_name='Radiohead', timestamp=1454746981),
#  Listen(song_name='Clarity (Radio Edit Version)', song_id=73517678, album_name='This Is Dance 2014', artist_name='ZEDD', timestamp=1454746745),
#  Listen(song_name='Girl From Mars', song_id=14063187, album_name='The Best Of Ash (Remastered)', artist_name='Ash', timestamp=1454746517),
#  Listen(song_name='Shut Up and Dance', song_id=84668483, album_name='Shut Up and Dance', artist_name='Walk The Moon', timestamp=1454705356),
#  Listen(song_name='Drops of Jupiter', song_id=13132946, album_name='Nice 2000s', artist_name='Train', timestamp=1454704792),
#  Listen(song_name='The River', song_id=65445759, album_name='Night Visions', artist_name='Imagine Dragons', timestamp=1454703980),
#  Listen(song_name='Round And Round', song_id=65445758, album_name='Night Visions', artist_name='Imagine Dragons', timestamp=1454703775),
#  Listen(song_name='My Fault', song_id=65445757, album_name='Night Visions', artist_name='Imagine Dragons', timestamp=1454703578),
#  Listen(song_name='Working Man', song_id=65445756, album_name='Night Visions', artist_name='Imagine Dragons', timestamp=1454703402),
#  Listen(song_name='Cha-Ching (Till We Grow Older)', song_id=65445755, album_name='Night Visions', artist_name='Imagine Dragons', timestamp=1454703166),
#  Listen(song_name="Don't Stop (Live)", song_id=67549276, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454690439),
#  Listen(song_name='Dreams (Live)', song_id=67549275, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454690214),
#  Listen(song_name='Monday Morning (Live)', song_id=67549274, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454689973),
#  Listen(song_name='Intro (Live)', song_id=67549273, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454689820),
#  Listen(song_name='Silver Springs (2004 Remastered Edition)', song_id=67549272, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454689778),
#  Listen(song_name='Gold Dust Woman (2004 Remastered Edition)', song_id=67549271, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454689495),
#  Listen(song_name='Oh Daddy (2004 Remastered Edition)', song_id=67549270, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454689206),
#  Listen(song_name="I Don't Want To Know (2004 Remastered Edition)", song_id=67549269, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454688976),
#  Listen(song_name='You Make Loving Fun (2004 Remastered Edition)', song_id=67549268, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454688785),
#  Listen(song_name='The Chain (2004 Remastered Edition)', song_id=67549267, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454688575),
#  Listen(song_name='Songbird (2004 Remastered Edition)', song_id=67549266, album_name='Rumours', artist_name='Fleetwood Mac', timestamp=1454687020)]

# %%
from collections import namedtuple

# %%
Listen = namedtuple('Listen', ['song_name', 'song_id', 'album_name', 'artist_name', "timestamp"], verbose=True)
# Out:
# from builtins import property as _property, tuple as _tuple
# from operator import itemgetter as _itemgetter
# from collections import OrderedDict
#
# class Listen(tuple):
#     'Listen(song_name, song_id, album_name, artist_name, timestamp)'
#
#     __slots__ = ()
#
#     _fields = ('song_name', 'song_id', 'album_name', 'artist_name', 'timestamp')
#
#     def __new__(_cls, song_name, song_id, album_name, artist_name, timestamp):
#         'Create new instance of Listen(song_name, song_id, album_name, artist_name, timestamp)'
#         return _tuple.__new__(_cls, (song_name, song_id, album_name, artist_name, timestamp))
#
#     @classmethod
#     def _make(cls, iterable, new=tuple.__new__, len=len):
#         'Make a new Listen object from a sequence or iterable'
#         result = new(cls, iterable)
#         if len(result) != 5:
#             raise TypeError('Expected 5 arguments, got %d' % len(result))
#         return result
#
#     def _replace(_self, **kwds):
#         'Return a new Listen object replacing specified fields with new values'
#         result = _self._make(map(kwds.pop, ('song_name', 'song_id', 'album_name', 'artist_name', 'timestamp'), _self))
#         if kwds:
#             raise ValueError('Got unexpected field names: %r' % list(kwds))
#         return result
#
#     def __repr__(self):
#         'Return a nicely formatted representation string'
#         return self.__class__.__name__ + '(song_name=%r, song_id=%r, album_name=%r, artist_name=%r, timestamp=%r)' % self
#
#     def _asdict(self):
#         'Return a new OrderedDict which maps field names to their values.'
#         return OrderedDict(zip(self._fields, self))
#
#     def __getnewargs__(self):
#         'Return self as a plain tuple.  Used by copy and pickle.'
#         return tuple(self)
#
#     song_name = _property(_itemgetter(0), doc='Alias for field number 0')
#
#     song_id = _property(_itemgetter(1), doc='Alias for field number 1')
#
#     album_name = _property(_itemgetter(2), doc='Alias for field number 2')
#
#     artist_name = _property(_itemgetter(3), doc='Alias for field number 3')
#
#     timestamp = _property(_itemgetter(4), doc='Alias for field number 4')

# %%
example = Listen("Defector", "Drones", "Muse", 1)

# %%
raw = get_history()
# Out:
# {'data': [{'link': 'http://www.deezer.com/track/70322138', 'preview': 'http://e-cdn-preview-3.deezer.com/stream/35992fcaa625b347111d9087b8065220-1.mp3', 'timestamp': 1454760031, 'album': {'cover_small': 'http://e-cdn-images.deezer.com/images/cover/4a7cad03696cf443b8b13bb67ec2d344/56x56-000000-80-0-0.jpg', 'title': 'AM', 'cover': 'http://api.deezer.com/album/6899610/image', 'type': 'album', 'link': 'http://www.deezer.com/album/6899610', 'cover_big': 'http://e-cdn-images.deezer.com/images/cover/4a7cad03696cf443b8b13bb67ec2d344/500x500-000000-80-0-0.jpg', 'tracklist': 'http://api.deezer.com/album/6899610/tracks', 'id': 6899610, 'cover_medium': 'http://e-cdn-images.deezer.com/images/cover/4a7cad03696cf443b8b13bb67ec2d344/250x250-000000-80-0-0.jpg'}, 'title_version': '', 'readable': True, 'title': 'Fireside', 'explicit_lyrics': False, 'type': 'track', 'artist': {'type': 'artist', 'name': 'Arctic Monkeys', 'tracklist': 'http://api.deezer.com/artist/1182/top?limit=50', 'id': 1182, 'link': 'http://www.deezer.com/artist/1182'}, 'duration': 181, 'title_short': 'Fireside', 'rank': 638314, 'id': 70322138}, {'link': 'http://www.deezer.com/track/70322137', 'preview': 'http://e-cdn-preview-1.deezer.com/stream/12e707a950533fd5fd3dbae290d247a4-1.mp3', 'timestamp': 1454759850, 'album': {'cover_small': 'http://e-cdn-images.deezer.com/images/cover/4a7cad03696cf443b8b13bb67ec2d344/56x56-000000-80-0-0.jpg', 'title': 'AM', 'cover': 'http://api.deezer.com/album/6899610/image', 'type': 'album', 'link': 'http://www.deezer.com/album/6899610', 'cover_big': 'http://e-cdn-images.deezer.com/images/cover/4a7cad03696cf443b8b13bb67ec2d344/500x500-000000-80-0-0.jpg', 'tracklist': 'http://api.deezer.com/album/6899610/tracks', 'id': 6899610, 'cover_medium': 'http://e-cdn-images.deezer.com/images/cover/4a7cad03696cf443b8b13bb67ec2d344/250x250-000000-80-0-0.jpg'}, 'title_version': '', 'readable': True, 'title': 'Mad Sounds', 'explicit_lyrics': False, 'type': 'track', 'artist': {'type': 'artist', 'name': 'Arctic Monkeys', 'tracklist': 'http://api.deezer.com/artist/1182/top?limit=50', 'id': 1182, 'link': 'http://www.deezer.com/artist/1182'}, 'duration': 215, 'title_short': 'Mad Sounds', 'rank': 654137, 'id': 70322137}, {'link': 'http://www.deezer.com/track/70322136', 'preview': 'http://e-cdn-preview-1.deezer.com/stream/15b93a9d09cc49828b3a7cfc5256b876-1.mp3', 'timestamp': 1454759634, 'album': {'cover_small': 'http://e-cdn-images.deezer.com/images/cover/4a7cad03696cf443b8b13bb67ec2d344/56x56-000000-80-0-0.jpg', 'title': 'AM', 'cover': 'http://api.deezer.com/album/6899610/image', 'type': 'album', 'link': 'http://www.deezer.com/album/6899610', 'cover_big': 'http://e-cdn-images.deezer.com/images/cover/4a7cad03696cf443b8b13bb67ec2d344/500x500-000000-80-0-0.jpg', 'tracklist': 'http://api.deezer.com/album/6899610/tracks', 'id': 6899610, 'cover_medium': 'http://e-cdn-images.deezer.com/images/cover/4a7cad03696cf443b8b13bb67ec2d344/250x250-000000-80-0-0.jpg'}, 'title_version': '', 'readable': True, 'title': 'No. 1 Party Anthem', 'explicit_lyrics': False, 'type': 'track', 'artist': {'type': 'artist', 'name': 'Arctic Monkeys', 'tracklist': 'http://api.deezer.com/artist/1182/top?limit=50', 'id': 1182, 'link': 'http://www.deezer.com/artist/1182'}, 'duration': 243, 'title_short': 'No. 1 Party Anthem', 'rank': 667197, 'id': 70322136}, {'link': 'http://www.deezer.com/track/70322135', 'preview': 'http://e-cdn-preview-c.deezer.com/stream/c6acd1e2ba5822ec70a985a229ecc39f-1.mp3', 'timestamp': 1454759391, 'album': {'cover_small': 'http://e-cdn-images.deezer.com/images/cover/4a7cad03696cf443b8b13bb67ec2d344/56x56-000000-80-0-0.jpg', 'title': 'AM', 'cover': 'http://api.deezer.com/album/6899610/image', 'type': 'album', 'link': 'http://www.deezer.com/album/6899610', 'cover_big': 'http://e-cdn-images.deezer.com/images/cover/4a7cad03696cf443b8b13bb67ec2d344/500x500-000000-80-0-0.jpg', 'tracklist': 'http://api.deezer.com/album/6899610/tracks', 'id': 6899610, 'cover_medium': 'http://e-cdn-images. ...

# %%
def process_history(data):
    return [Listen(item["title"], item["id"], item["album"]["title"], item["artist"]["name"], item["timestamp"]) for item in data["data"]]

# %%
longHistory = get_history(length = 1000)

# %%
listenHistory = process_history(historyExample)

# %%
import numpy as np
# %matplotlib inline
from IPython.core.pylabtools import figsize
from matplotlib import pyplot as plt
from collections import Counter

# %%
timestamps = [x.timestamp for x in longHistory]
artists = [x.artist_name for x in longHistory]
# Out:
# Counter({'Ash': 1,
#          'Fleetwood Mac': 16,
#          'Imagine Dragons': 5,
#          'Muse': 24,
#          'Radiohead': 1,
#          'Train': 1,
#          'Walk The Moon': 1,
#          'ZEDD': 1})

# %%
def display_pie_chart(listenHistory, number_items = 10):
    artists = [x.artist_name for x in listenHistory]
    counter = Counter(artists)
    
    artists, count = [x[0] for x in counter.most_common(number_items)], [x[1] for x in counter.most_common(number_items)]
    plt.pie(count, labels = artists)

# %%
display_pie_chart(longHistory, number_items = 20 )

# %%
def most_listened_to_songs(listenHistory, number_items = 10):
    titles = [x.song_id for x in listenHistory]
    counter = Counter(titles)
    return counter.most_common(10)

# %%
",".join([str(x[0]) for x in most_listened_to_songs(longHistory)])
# Out:
# '4286053,14063187,63480987,63480990,73517678,4094753,63480992,67549261,4094757,67549263'

# %%
class Playlist:
    
    def __init__(self, p_id = 1609467705,name = "JakesSuperAmazingFlow"):
        self.name = name
        self.url = r"http://api.deezer.com/playlist/{0}/tracks?access_token={1}".format(p_id,access_token)
        self.p_id = p_id

    def create(self):
        return False
        
    def add_tracks(self, ids):
        url = self.url + "&songs=" + self._parse_track_input(ids)
        return requests.post(url).json()
    
    def get_tracks(self):
        return requests.get(self.url).json()
    
    def remove_tracks(self, ids):
        url = self.url + "&songs=" + self._parse_track_input(ids)
        requests.delete(url)
        
    def clear_tracks(self):
        tracks = [x["id"] for x in playlist.get_tracks()["data"]]
        while tracks != []:
            self.remove_tracks(tracks)
            tracks = [x["id"] for x in playlist.get_tracks()["data"]]
    
    
    def _parse_track_input(self, ids):
        return "%2C".join([str(id) for id in ids])

# %%
playlist = Playlist()

# %%
playlist.clear_tracks()

# %%
# Out:
# [4286053]
