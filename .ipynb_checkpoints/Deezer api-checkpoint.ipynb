# %%
import requests

# %%
apiEndPoints = {
    "album": r"https://api.deezer.com/album/{0}",
    "artist": r"https://api.deezer.com/artist/{0}",
    "track": r"https://api.deezer.com/track/{0}"    
}

# %%
access_token = "frBx6ZdRjE553f9dc2a3cc9P7JptufC553f9dc2a3d00hX24wk"

# %%
def get_item_from_api(itemType, itemId):
    r = requests.get(url = apiEndPoints[itemType].format(itemId))
    return r.json()

# %%
get_item_from_api("artist", 27)
# Out:
# {'id': 27,
#  'link': 'https://www.deezer.com/artist/27',
#  'name': 'Daft Punk',
#  'nb_album': 30,
#  'nb_fan': 3025968,
#  'picture': 'https://api.deezer.com/artist/27/image',
#  'picture_big': 'https://cdns-images.dzcdn.net/images/artist/f2bc007e9133c946ac3c3907ddc5d2ea/500x500-000000-80-0-0.jpg',
#  'picture_medium': 'https://cdns-images.dzcdn.net/images/artist/f2bc007e9133c946ac3c3907ddc5d2ea/250x250-000000-80-0-0.jpg',
#  'picture_small': 'https://cdns-images.dzcdn.net/images/artist/f2bc007e9133c946ac3c3907ddc5d2ea/56x56-000000-80-0-0.jpg',
#  'radio': True,
#  'share': 'http://www.deezer.com/artist/27?utm_source=deezer&utm_content=artist-27&utm_term=0_1454754910&utm_medium=web',
#  'tracklist': 'https://api.deezer.com/artist/27/top?limit=50',
#  'type': 'artist'}

# %%
def get_history():
    url = r"http://api.deezer.com/user/me/history?access_token=" + access_token
    return requests.get(url = url).json()

# %%
get_history()
# Out:
# {'data': [{'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 245,
#    'explicit_lyrics': False,
#    'id': 101215858,
#    'link': 'http://www.deezer.com/track/101215858',
#    'preview': 'http://e-cdn-preview-a.deezer.com/stream/a53d239a2ec0a4135cdf50fa16d99558-0.mp3',
#    'rank': 690922,
#    'readable': True,
#    'timestamp': 1454755298,
#    'title': 'Revolt',
#    'title_short': 'Revolt',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 273,
#    'explicit_lyrics': False,
#    'id': 101215856,
#    'link': 'http://www.deezer.com/track/101215856',
#    'preview': 'http://e-cdn-preview-f.deezer.com/stream/fa2166cb270934f779d4168826fbf794-0.mp3',
#    'rank': 703724,
#    'readable': True,
#    'timestamp': 1454755052,
#    'title': 'Defector',
#    'title_short': 'Defector',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 54,
#    'explicit_lyrics': False,
#    'id': 101215854,
#    'link': 'http://www.deezer.com/track/101215854',
#    'preview': 'http://e-cdn-preview-b.deezer.com/stream/b83b1ceb306b354e378cbe0a1da79a38-0.mp3',
#    'rank': 682150,
#    'readable': True,
#    'timestamp': 1454754779,
#    'title': '[JFK]',
#    'title_short': '[JFK]',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 273,
#    'explicit_lyrics': False,
#    'id': 101215852,
#    'link': 'http://www.deezer.com/track/101215852',
#    'preview': 'http://e-cdn-preview-7.deezer.com/stream/7b2427dc21cbf98aaf24fd5e565766fb-0.mp3',
#    'rank': 719743,
#    'readable': True,
#    'timestamp': 1454754724,
#    'title': 'The Handler',
#    'title_short': 'The Handler',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 359,
#    'explicit_lyrics': False,
#    'id': 101215850,
#    'link': 'http://www.deezer.com/track/101215850',
#    'preview': 'http://e-cdn-preview-d.deezer.com/stream/d8fbecfa126968f69db3f0fdc1183fff-0.mp3',
#    'rank': 740430,
#    'readable': True,
#    'timestamp': 1454754450,
#    'title': 'Reapers',
#    'title_short': 'Reapers',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 231,
#    'explicit_lyrics': False,
#    'id': 101215848,
#    'link': 'http://www.deezer.com/track/101215848',
#    'preview': 'http://e-cdn-preview-6.deezer.com/stream/6cf06302aa5f1466fbfaf679618a4826-0.mp3',
#    'rank': 804463,
#    'readable': True,
#    'timestamp': 1454754092,
#    'title': 'Mercy',
#    'title_short': 'Mercy',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/302490/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/6a60c8f7d5557496ae956df058f7296d/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/6a60c8f7d5557496ae956df058f7296d/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/6a60c8f7d5557496ae956df058f7296d/56x56-000000-80-0-0.jpg',
#     'id': 302490,
#     'link': 'http://www.deezer.com/album/302490',
#     'title': 'The Best Of',
#     'tracklist': 'http://api.deezer.com/album/302490/tracks',
#     'type': 'album'},
#    'artist': {'id': 399,
#     'link': 'http://www.deezer.com/artist/399',
#     'name': 'Radiohead',
#     'tracklist': 'http://api.deezer.com/artist/399/top?limit=50',
#     'type': 'artist'},
#    'duration': 234,
#    'explicit_lyrics': False,
#    'id': 3140486,
#    'link': 'http://www.deezer.com/track/3140486',
#    'preview': 'http://e-cdn-preview-2.deezer.com/stream/27c4ade4779a9507cea295542ab373e3-4.mp3',
#    'rank': 556320,
#    'readable': True,
#    'timestamp': 1454746981,
#    'title': 'Just',
#    'title_short': 'Just',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/7241043/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/1791c5ca76318593d06e55094cd6434e/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/1791c5ca76318593d06e55094cd6434e/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/1791c5ca76318593d06e55094cd6434e/56x56-000000-80-0-0.jpg',
#     'id': 7241043,
#     'link': 'http://www.deezer.com/album/7241043',
#     'title': 'This Is Dance 2014',
#     'tracklist': 'http://api.deezer.com/album/7241043/tracks',
#     'type': 'album'},
#    'artist': {'id': 1198612,
#     'link': 'http://www.deezer.com/artist/1198612',
#     'name': 'ZEDD',
#     'tracklist': 'http://api.deezer.com/artist/1198612/top?limit=50',
#     'type': 'artist'},
#    'duration': 228,
#    'explicit_lyrics': False,
#    'id': 73517678,
#    'link': 'http://www.deezer.com/track/73517678',
#    'preview': 'http://e-cdn-preview-a.deezer.com/stream/ae056bcde6068ed2d24ba087493eea80-1.mp3',
#    'rank': 588236,
#    'readable': True,
#    'timestamp': 1454746745,
#    'title': 'Clarity (Radio Edit Version)',
#    'title_short': 'Clarity',
#    'title_version': '(Radio Edit Version)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/1288621/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/ca997a0c237515ee2817ce652a1e9fbd/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/ca997a0c237515ee2817ce652a1e9fbd/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/ca997a0c237515ee2817ce652a1e9fbd/56x56-000000-80-0-0.jpg',
#     'id': 1288621,
#     'link': 'http://www.deezer.com/album/1288621',
#     'title': 'The Best Of Ash (Remastered)',
#     'tracklist': 'http://api.deezer.com/album/1288621/tracks',
#     'type': 'album'},
#    'artist': {'id': 1781,
#     'link': 'http://www.deezer.com/artist/1781',
#     'name': 'Ash',
#     'tracklist': 'http://api.deezer.com/artist/1781/top?limit=50',
#     'type': 'artist'},
#    'duration': 213,
#    'explicit_lyrics': False,
#    'id': 14063187,
#    'link': 'http://www.deezer.com/track/14063187',
#    'preview': 'http://e-cdn-preview-3.deezer.com/stream/30c9e323e37dcd7be95afae8067cebaa-2.mp3',
#    'rank': 505142,
#    'readable': True,
#    'timestamp': 1454746517,
#    'title': 'Girl From Mars',
#    'title_short': 'Girl From Mars',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/8535737/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/7f3d5b5c3c0358e3edc58ee8d9f6cabb/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/7f3d5b5c3c0358e3edc58ee8d9f6cabb/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/7f3d5b5c3c0358e3edc58ee8d9f6cabb/56x56-000000-80-0-0.jpg',
#     'id': 8535737,
#     'link': 'http://www.deezer.com/album/8535737',
#     'title': 'Shut Up and Dance',
#     'tracklist': 'http://api.deezer.com/album/8535737/tracks',
#     'type': 'album'},
#    'artist': {'id': 525307,
#     'link': 'http://www.deezer.com/artist/525307',
#     'name': 'Walk The Moon',
#     'tracklist': 'http://api.deezer.com/artist/525307/top?limit=50',
#     'type': 'artist'},
#    'duration': 197,
#    'explicit_lyrics': False,
#    'id': 84668483,
#    'link': 'http://www.deezer.com/track/84668483',
#    'preview': 'http://e-cdn-preview-f.deezer.com/stream/fbba3a451d71344053e8d2e22b4fbffd-1.mp3',
#    'rank': 964398,
#    'readable': True,
#    'timestamp': 1454705356,
#    'title': 'Shut Up and Dance',
#    'title_short': 'Shut Up and Dance',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/1205360/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/e6f5530da77fd2bc2e01af26cf620852/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/e6f5530da77fd2bc2e01af26cf620852/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/e6f5530da77fd2bc2e01af26cf620852/56x56-000000-80-0-0.jpg',
#     'id': 1205360,
#     'link': 'http://www.deezer.com/album/1205360',
#     'title': 'Nice 2000s',
#     'tracklist': 'http://api.deezer.com/album/1205360/tracks',
#     'type': 'album'},
#    'artist': {'id': 685,
#     'link': 'http://www.deezer.com/artist/685',
#     'name': 'Train',
#     'tracklist': 'http://api.deezer.com/artist/685/top?limit=50',
#     'type': 'artist'},
#    'duration': 260,
#    'explicit_lyrics': False,
#    'id': 13132946,
#    'link': 'http://www.deezer.com/track/13132946',
#    'preview': 'http://e-cdn-preview-f.deezer.com/stream/f7d2f9553c4788426c50ff623cb1ab77-5.mp3',
#    'rank': 476300,
#    'readable': True,
#    'timestamp': 1454704792,
#    'title': 'Drops of Jupiter',
#    'title_short': 'Drops of Jupiter',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6415278/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/56x56-000000-80-0-0.jpg',
#     'id': 6415278,
#     'link': 'http://www.deezer.com/album/6415278',
#     'title': 'Night Visions',
#     'tracklist': 'http://api.deezer.com/album/6415278/tracks',
#     'type': 'album'},
#    'artist': {'id': 416239,
#     'link': 'http://www.deezer.com/artist/416239',
#     'name': 'Imagine Dragons',
#     'tracklist': 'http://api.deezer.com/artist/416239/top?limit=50',
#     'type': 'artist'},
#    'duration': 204,
#    'explicit_lyrics': False,
#    'id': 65445759,
#    'link': 'http://www.deezer.com/track/65445759',
#    'preview': 'http://e-cdn-preview-0.deezer.com/stream/0e60f70c6dff3572411180f8cdf72d95-3.mp3',
#    'rank': 479526,
#    'readable': True,
#    'timestamp': 1454703980,
#    'title': 'The River',
#    'title_short': 'The River',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6415278/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/56x56-000000-80-0-0.jpg',
#     'id': 6415278,
#     'link': 'http://www.deezer.com/album/6415278',
#     'title': 'Night Visions',
#     'tracklist': 'http://api.deezer.com/album/6415278/tracks',
#     'type': 'album'},
#    'artist': {'id': 416239,
#     'link': 'http://www.deezer.com/artist/416239',
#     'name': 'Imagine Dragons',
#     'tracklist': 'http://api.deezer.com/artist/416239/top?limit=50',
#     'type': 'artist'},
#    'duration': 197,
#    'explicit_lyrics': False,
#    'id': 65445758,
#    'link': 'http://www.deezer.com/track/65445758',
#    'preview': 'http://e-cdn-preview-f.deezer.com/stream/ff129a0ca2495b352a94d906ff4a3eaf-3.mp3',
#    'rank': 549932,
#    'readable': True,
#    'timestamp': 1454703775,
#    'title': 'Round And Round',
#    'title_short': 'Round And Round',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6415278/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/56x56-000000-80-0-0.jpg',
#     'id': 6415278,
#     'link': 'http://www.deezer.com/album/6415278',
#     'title': 'Night Visions',
#     'tracklist': 'http://api.deezer.com/album/6415278/tracks',
#     'type': 'album'},
#    'artist': {'id': 416239,
#     'link': 'http://www.deezer.com/artist/416239',
#     'name': 'Imagine Dragons',
#     'tracklist': 'http://api.deezer.com/artist/416239/top?limit=50',
#     'type': 'artist'},
#    'duration': 175,
#    'explicit_lyrics': False,
#    'id': 65445757,
#    'link': 'http://www.deezer.com/track/65445757',
#    'preview': 'http://e-cdn-preview-3.deezer.com/stream/3a84f1dd1cfaf2ba2f4f271268c01762-3.mp3',
#    'rank': 512402,
#    'readable': True,
#    'timestamp': 1454703578,
#    'title': 'My Fault',
#    'title_short': 'My Fault',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6415278/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/56x56-000000-80-0-0.jpg',
#     'id': 6415278,
#     'link': 'http://www.deezer.com/album/6415278',
#     'title': 'Night Visions',
#     'tracklist': 'http://api.deezer.com/album/6415278/tracks',
#     'type': 'album'},
#    'artist': {'id': 416239,
#     'link': 'http://www.deezer.com/artist/416239',
#     'name': 'Imagine Dragons',
#     'tracklist': 'http://api.deezer.com/artist/416239/top?limit=50',
#     'type': 'artist'},
#    'duration': 235,
#    'explicit_lyrics': False,
#    'id': 65445756,
#    'link': 'http://www.deezer.com/track/65445756',
#    'preview': 'http://e-cdn-preview-6.deezer.com/stream/610386febf057fe82c52aa451371cbe1-3.mp3',
#    'rank': 462871,
#    'readable': True,
#    'timestamp': 1454703402,
#    'title': 'Working Man',
#    'title_short': 'Working Man',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6415278/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/f6c82c7d673bdf0373a457e52dfcdb36/56x56-000000-80-0-0.jpg',
#     'id': 6415278,
#     'link': 'http://www.deezer.com/album/6415278',
#     'title': 'Night Visions',
#     'tracklist': 'http://api.deezer.com/album/6415278/tracks',
#     'type': 'album'},
#    'artist': {'id': 416239,
#     'link': 'http://www.deezer.com/artist/416239',
#     'name': 'Imagine Dragons',
#     'tracklist': 'http://api.deezer.com/artist/416239/top?limit=50',
#     'type': 'artist'},
#    'duration': 249,
#    'explicit_lyrics': False,
#    'id': 65445755,
#    'link': 'http://www.deezer.com/track/65445755',
#    'preview': 'http://e-cdn-preview-9.deezer.com/stream/955e6c1bba68d93d29cb1d0e11047760-3.mp3',
#    'rank': 457884,
#    'readable': True,
#    'timestamp': 1454703166,
#    'title': 'Cha-Ching (Till We Grow Older)',
#    'title_short': 'Cha-Ching (Till We Grow Older)',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 231,
#    'explicit_lyrics': False,
#    'id': 67549276,
#    'link': 'http://www.deezer.com/track/67549276',
#    'preview': 'http://e-cdn-preview-e.deezer.com/stream/efda15fe2d503163e3f9a34fa56ed492-2.mp3',
#    'rank': 423233,
#    'readable': True,
#    'timestamp': 1454690439,
#    'title': "Don't Stop (Live)",
#    'title_short': "Don't Stop",
#    'title_version': '(Live)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 247,
#    'explicit_lyrics': False,
#    'id': 67549275,
#    'link': 'http://www.deezer.com/track/67549275',
#    'preview': 'http://e-cdn-preview-4.deezer.com/stream/4fd0a7e765adc7e31468ae11c29af1eb-2.mp3',
#    'rank': 442929,
#    'readable': True,
#    'timestamp': 1454690214,
#    'title': 'Dreams (Live)',
#    'title_short': 'Dreams',
#    'title_version': '(Live)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 158,
#    'explicit_lyrics': False,
#    'id': 67549274,
#    'link': 'http://www.deezer.com/track/67549274',
#    'preview': 'http://e-cdn-preview-9.deezer.com/stream/980a0700b417c3e2792c828a7248722c-2.mp3',
#    'rank': 406838,
#    'readable': True,
#    'timestamp': 1454689973,
#    'title': 'Monday Morning (Live)',
#    'title_short': 'Monday Morning',
#    'title_version': '(Live)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 48,
#    'explicit_lyrics': False,
#    'id': 67549273,
#    'link': 'http://www.deezer.com/track/67549273',
#    'preview': 'http://e-cdn-preview-a.deezer.com/stream/ac2d38e88b1bca3f1cd150eefe424fde-2.mp3',
#    'rank': 408041,
#    'readable': True,
#    'timestamp': 1454689820,
#    'title': 'Intro (Live)',
#    'title_short': 'Intro',
#    'title_version': '(Live)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 288,
#    'explicit_lyrics': False,
#    'id': 67549272,
#    'link': 'http://www.deezer.com/track/67549272',
#    'preview': 'http://e-cdn-preview-d.deezer.com/stream/d704c6a4eb96b5be715c111f54101e6c-3.mp3',
#    'rank': 444185,
#    'readable': True,
#    'timestamp': 1454689778,
#    'title': 'Silver Springs (2004 Remastered Edition)',
#    'title_short': 'Silver Springs',
#    'title_version': '(2004 Remastered Edition)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 295,
#    'explicit_lyrics': False,
#    'id': 67549271,
#    'link': 'http://www.deezer.com/track/67549271',
#    'preview': 'http://e-cdn-preview-d.deezer.com/stream/d4df941c8a412a6db8b55084a0e674c4-3.mp3',
#    'rank': 490379,
#    'readable': True,
#    'timestamp': 1454689495,
#    'title': 'Gold Dust Woman (2004 Remastered Edition)',
#    'title_short': 'Gold Dust Woman',
#    'title_version': '(2004 Remastered Edition)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 236,
#    'explicit_lyrics': False,
#    'id': 67549270,
#    'link': 'http://www.deezer.com/track/67549270',
#    'preview': 'http://e-cdn-preview-3.deezer.com/stream/30638a76cc9189e2b0f14fd4862289f1-3.mp3',
#    'rank': 479011,
#    'readable': True,
#    'timestamp': 1454689206,
#    'title': 'Oh Daddy (2004 Remastered Edition)',
#    'title_short': 'Oh Daddy',
#    'title_version': '(2004 Remastered Edition)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 196,
#    'explicit_lyrics': False,
#    'id': 67549269,
#    'link': 'http://www.deezer.com/track/67549269',
#    'preview': 'http://e-cdn-preview-d.deezer.com/stream/d8799201885a6e179e775610023a8da4-3.mp3',
#    'rank': 479620,
#    'readable': True,
#    'timestamp': 1454688976,
#    'title': "I Don't Want To Know (2004 Remastered Edition)",
#    'title_short': "I Don't Want To Know",
#    'title_version': '(2004 Remastered Edition)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 216,
#    'explicit_lyrics': False,
#    'id': 67549268,
#    'link': 'http://www.deezer.com/track/67549268',
#    'preview': 'http://e-cdn-preview-6.deezer.com/stream/67a3e48426fc83742273f36b0f73b3d3-3.mp3',
#    'rank': 547299,
#    'readable': True,
#    'timestamp': 1454688785,
#    'title': 'You Make Loving Fun (2004 Remastered Edition)',
#    'title_short': 'You Make Loving Fun',
#    'title_version': '(2004 Remastered Edition)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 270,
#    'explicit_lyrics': False,
#    'id': 67549267,
#    'link': 'http://www.deezer.com/track/67549267',
#    'preview': 'http://e-cdn-preview-4.deezer.com/stream/4e77ced188b4d08c19e1c8a46aad5a56-3.mp3',
#    'rank': 536453,
#    'readable': True,
#    'timestamp': 1454688575,
#    'title': 'The Chain (2004 Remastered Edition)',
#    'title_short': 'The Chain',
#    'title_version': '(2004 Remastered Edition)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 200,
#    'explicit_lyrics': False,
#    'id': 67549266,
#    'link': 'http://www.deezer.com/track/67549266',
#    'preview': 'http://e-cdn-preview-f.deezer.com/stream/fa3718a931164d22b08803135fdd195d-6.mp3',
#    'rank': 589099,
#    'readable': True,
#    'timestamp': 1454687020,
#    'title': 'Songbird (2004 Remastered Edition)',
#    'title_short': 'Songbird',
#    'title_version': '(2004 Remastered Edition)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 223,
#    'explicit_lyrics': False,
#    'id': 67549265,
#    'link': 'http://www.deezer.com/track/67549265',
#    'preview': 'http://e-cdn-preview-b.deezer.com/stream/b9f7cdff2c72b9b13238a9ccd351860c-2.mp3',
#    'rank': 577329,
#    'readable': True,
#    'timestamp': 1454686825,
#    'title': 'Go Your Own Way (2004 Remastered Edition)',
#    'title_short': 'Go Your Own Way',
#    'title_version': '(2004 Remastered Edition)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 193,
#    'explicit_lyrics': False,
#    'id': 67549264,
#    'link': 'http://www.deezer.com/track/67549264',
#    'preview': 'http://e-cdn-preview-a.deezer.com/stream/a2a9bd78afd975c49254e6e29ff948d8-2.mp3',
#    'rank': 665513,
#    'readable': True,
#    'timestamp': 1454686605,
#    'title': "Don't Stop (2004 Remastered Edition)",
#    'title_short': "Don't Stop",
#    'title_version': '(2004 Remastered Edition)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 134,
#    'explicit_lyrics': False,
#    'id': 67549263,
#    'link': 'http://www.deezer.com/track/67549263',
#    'preview': 'http://e-cdn-preview-c.deezer.com/stream/c830455b9b8b5e10bf75f36b9e72dd5f-2.mp3',
#    'rank': 556515,
#    'readable': True,
#    'timestamp': 1454686418,
#    'title': 'Never Going Back Again (2004 Remastered Edition)',
#    'title_short': 'Never Going Back Again',
#    'title_version': '(2004 Remastered Edition)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 257,
#    'explicit_lyrics': False,
#    'id': 67549262,
#    'link': 'http://www.deezer.com/track/67549262',
#    'preview': 'http://e-cdn-preview-7.deezer.com/stream/775a6ad14d84891f97c64cc0569d3ad2-3.mp3',
#    'rank': 637483,
#    'readable': True,
#    'timestamp': 1454686290,
#    'title': 'Dreams (2004 Remastered Edition)',
#    'title_short': 'Dreams',
#    'title_version': '(2004 Remastered Edition)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/6612817/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/0199f3f00d23ed0916cf748d9b5d5030/56x56-000000-80-0-0.jpg',
#     'id': 6612817,
#     'link': 'http://www.deezer.com/album/6612817',
#     'title': 'Rumours',
#     'tracklist': 'http://api.deezer.com/album/6612817/tracks',
#     'type': 'album'},
#    'artist': {'id': 169,
#     'link': 'http://www.deezer.com/artist/169',
#     'name': 'Fleetwood Mac',
#     'tracklist': 'http://api.deezer.com/artist/169/top?limit=50',
#     'type': 'artist'},
#    'duration': 176,
#    'explicit_lyrics': False,
#    'id': 67549261,
#    'link': 'http://www.deezer.com/track/67549261',
#    'preview': 'http://e-cdn-preview-2.deezer.com/stream/2205e5a9fd291067ee3d77e7ecd1f1e9-2.mp3',
#    'rank': 566248,
#    'readable': True,
#    'timestamp': 1454686039,
#    'title': 'Second Hand News (2004 Remastered Edition)',
#    'title_short': 'Second Hand News',
#    'title_version': '(2004 Remastered Edition)',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 607,
#    'explicit_lyrics': False,
#    'id': 101215862,
#    'link': 'http://www.deezer.com/track/101215862',
#    'preview': 'http://e-cdn-preview-c.deezer.com/stream/cdd99745c0044255b30391e21c4cf728-0.mp3',
#    'rank': 643122,
#    'readable': True,
#    'timestamp': 1454685869,
#    'title': 'The Globalist',
#    'title_short': 'The Globalist',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 347,
#    'explicit_lyrics': False,
#    'id': 101215860,
#    'link': 'http://www.deezer.com/track/101215860',
#    'preview': 'http://e-cdn-preview-2.deezer.com/stream/2845b47e4d72d49f1fd329f891bb7df4-0.mp3',
#    'rank': 671304,
#    'readable': True,
#    'timestamp': 1454685771,
#    'title': 'Aftermath',
#    'title_short': 'Aftermath',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 245,
#    'explicit_lyrics': False,
#    'id': 101215858,
#    'link': 'http://www.deezer.com/track/101215858',
#    'preview': 'http://e-cdn-preview-a.deezer.com/stream/a53d239a2ec0a4135cdf50fa16d99558-0.mp3',
#    'rank': 690922,
#    'readable': True,
#    'timestamp': 1454685430,
#    'title': 'Revolt',
#    'title_short': 'Revolt',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 273,
#    'explicit_lyrics': False,
#    'id': 101215856,
#    'link': 'http://www.deezer.com/track/101215856',
#    'preview': 'http://e-cdn-preview-f.deezer.com/stream/fa2166cb270934f779d4168826fbf794-0.mp3',
#    'rank': 703724,
#    'readable': True,
#    'timestamp': 1454685190,
#    'title': 'Defector',
#    'title_short': 'Defector',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 54,
#    'explicit_lyrics': False,
#    'id': 101215854,
#    'link': 'http://www.deezer.com/track/101215854',
#    'preview': 'http://e-cdn-preview-b.deezer.com/stream/b83b1ceb306b354e378cbe0a1da79a38-0.mp3',
#    'rank': 682150,
#    'readable': True,
#    'timestamp': 1454684924,
#    'title': '[JFK]',
#    'title_short': '[JFK]',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 273,
#    'explicit_lyrics': False,
#    'id': 101215852,
#    'link': 'http://www.deezer.com/track/101215852',
#    'preview': 'http://e-cdn-preview-7.deezer.com/stream/7b2427dc21cbf98aaf24fd5e565766fb-0.mp3',
#    'rank': 719743,
#    'readable': True,
#    'timestamp': 1454684875,
#    'title': 'The Handler',
#    'title_short': 'The Handler',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 359,
#    'explicit_lyrics': False,
#    'id': 101215850,
#    'link': 'http://www.deezer.com/track/101215850',
#    'preview': 'http://e-cdn-preview-d.deezer.com/stream/d8fbecfa126968f69db3f0fdc1183fff-0.mp3',
#    'rank': 740430,
#    'readable': True,
#    'timestamp': 1454684608,
#    'title': 'Reapers',
#    'title_short': 'Reapers',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 231,
#    'explicit_lyrics': False,
#    'id': 101215848,
#    'link': 'http://www.deezer.com/track/101215848',
#    'preview': 'http://e-cdn-preview-6.deezer.com/stream/6cf06302aa5f1466fbfaf679618a4826-0.mp3',
#    'rank': 804463,
#    'readable': True,
#    'timestamp': 1454684255,
#    'title': 'Mercy',
#    'title_short': 'Mercy',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 316,
#    'explicit_lyrics': True,
#    'id': 101215846,
#    'link': 'http://www.deezer.com/track/101215846',
#    'preview': 'http://e-cdn-preview-8.deezer.com/stream/878da49c8a3f9e6c245a1f823f6dc9aa-0.mp3',
#    'rank': 846013,
#    'readable': True,
#    'timestamp': 1454684029,
#    'title': 'Psycho',
#    'title_short': 'Psycho',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 262,
#    'explicit_lyrics': False,
#    'id': 101215842,
#    'link': 'http://www.deezer.com/track/101215842',
#    'preview': 'http://e-cdn-preview-7.deezer.com/stream/7fb11363dc4f88d4b52c8776bf12b9b4-0.mp3',
#    'rank': 800726,
#    'readable': True,
#    'timestamp': 1454683703,
#    'title': 'Dead Inside',
#    'title_short': 'Dead Inside',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 169,
#    'explicit_lyrics': False,
#    'id': 101215864,
#    'link': 'http://www.deezer.com/track/101215864',
#    'preview': 'http://e-cdn-preview-a.deezer.com/stream/a2462c0530a2012266c58ce3422fb20d-0.mp3',
#    'rank': 635566,
#    'readable': True,
#    'timestamp': 1454673845,
#    'title': 'Drones',
#    'title_short': 'Drones',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 607,
#    'explicit_lyrics': False,
#    'id': 101215862,
#    'link': 'http://www.deezer.com/track/101215862',
#    'preview': 'http://e-cdn-preview-c.deezer.com/stream/cdd99745c0044255b30391e21c4cf728-0.mp3',
#    'rank': 643122,
#    'readable': True,
#    'timestamp': 1454673682,
#    'title': 'The Globalist',
#    'title_short': 'The Globalist',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 347,
#    'explicit_lyrics': False,
#    'id': 101215860,
#    'link': 'http://www.deezer.com/track/101215860',
#    'preview': 'http://e-cdn-preview-2.deezer.com/stream/2845b47e4d72d49f1fd329f891bb7df4-0.mp3',
#    'rank': 671304,
#    'readable': True,
#    'timestamp': 1454673081,
#    'title': 'Aftermath',
#    'title_short': 'Aftermath',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 245,
#    'explicit_lyrics': False,
#    'id': 101215858,
#    'link': 'http://www.deezer.com/track/101215858',
#    'preview': 'http://e-cdn-preview-a.deezer.com/stream/a53d239a2ec0a4135cdf50fa16d99558-0.mp3',
#    'rank': 690922,
#    'readable': True,
#    'timestamp': 1454672739,
#    'title': 'Revolt',
#    'title_short': 'Revolt',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 273,
#    'explicit_lyrics': False,
#    'id': 101215856,
#    'link': 'http://www.deezer.com/track/101215856',
#    'preview': 'http://e-cdn-preview-f.deezer.com/stream/fa2166cb270934f779d4168826fbf794-0.mp3',
#    'rank': 703724,
#    'readable': True,
#    'timestamp': 1454672499,
#    'title': 'Defector',
#    'title_short': 'Defector',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 54,
#    'explicit_lyrics': False,
#    'id': 101215854,
#    'link': 'http://www.deezer.com/track/101215854',
#    'preview': 'http://e-cdn-preview-b.deezer.com/stream/b83b1ceb306b354e378cbe0a1da79a38-0.mp3',
#    'rank': 682150,
#    'readable': True,
#    'timestamp': 1454672233,
#    'title': '[JFK]',
#    'title_short': '[JFK]',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 273,
#    'explicit_lyrics': False,
#    'id': 101215852,
#    'link': 'http://www.deezer.com/track/101215852',
#    'preview': 'http://e-cdn-preview-7.deezer.com/stream/7b2427dc21cbf98aaf24fd5e565766fb-0.mp3',
#    'rank': 719743,
#    'readable': True,
#    'timestamp': 1454672184,
#    'title': 'The Handler',
#    'title_short': 'The Handler',
#    'title_version': '',
#    'type': 'track'},
#   {'album': {'cover': 'http://api.deezer.com/album/10506072/image',
#     'cover_big': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/500x500-000000-80-0-0.jpg',
#     'cover_medium': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/250x250-000000-80-0-0.jpg',
#     'cover_small': 'http://cdn-images.deezer.com/images/cover/4288439f650f1f592121011c44c7ca85/56x56-000000-80-0-0.jpg',
#     'id': 10506072,
#     'link': 'http://www.deezer.com/album/10506072',
#     'title': 'Drones',
#     'tracklist': 'http://api.deezer.com/album/10506072/tracks',
#     'type': 'album'},
#    'artist': {'id': 705,
#     'link': 'http://www.deezer.com/artist/705',
#     'name': 'Muse',
#     'tracklist': 'http://api.deezer.com/artist/705/top?limit=50',
#     'type': 'artist'},
#    'duration': 359,
#    'explicit_lyrics': False,
#    'id': 101215850,
#    'link': 'http://www.deezer.com/track/101215850',
#    'preview': 'http://e-cdn-preview-d.deezer.com/stream/d8fbecfa126968f69db3f0fdc1183fff-0.mp3',
#    'rank': 740430,
#    'readable': True,
#    'timestamp': 1454671917,
#    'title': 'Reapers',
#    'title_short': 'Reapers',
#    'title_version': '',
#    'type': 'track'}],
#  'next': 'http://api.deezer.com/user/me/history?access_token=frBx6ZdRjE553f9dc2a3cc9P7JptufC553f9dc2a3d00hX24wk&index=50',
#  'total': 82}

# %%
from collections import namedtuple

# %%
Listen = namedtuple('Listen', ['song_name', 'album_name', 'artist_name', "timestamp"], verbose=True)
# Out:
# from builtins import property as _property, tuple as _tuple
# from operator import itemgetter as _itemgetter
# from collections import OrderedDict
#
# class Listen(tuple):
#     'Listen(song_name, album_name, artist_name, timestamp)'
#
#     __slots__ = ()
#
#     _fields = ('song_name', 'album_name', 'artist_name', 'timestamp')
#
#     def __new__(_cls, song_name, album_name, artist_name, timestamp):
#         'Create new instance of Listen(song_name, album_name, artist_name, timestamp)'
#         return _tuple.__new__(_cls, (song_name, album_name, artist_name, timestamp))
#
#     @classmethod
#     def _make(cls, iterable, new=tuple.__new__, len=len):
#         'Make a new Listen object from a sequence or iterable'
#         result = new(cls, iterable)
#         if len(result) != 4:
#             raise TypeError('Expected 4 arguments, got %d' % len(result))
#         return result
#
#     def _replace(_self, **kwds):
#         'Return a new Listen object replacing specified fields with new values'
#         result = _self._make(map(kwds.pop, ('song_name', 'album_name', 'artist_name', 'timestamp'), _self))
#         if kwds:
#             raise ValueError('Got unexpected field names: %r' % list(kwds))
#         return result
#
#     def __repr__(self):
#         'Return a nicely formatted representation string'
#         return self.__class__.__name__ + '(song_name=%r, album_name=%r, artist_name=%r, timestamp=%r)' % self
#
#     def _asdict(self):
#         'Return a new OrderedDict which maps field names to their values.'
#         return OrderedDict(zip(self._fields, self))
#
#     def __getnewargs__(self):
#         'Return self as a plain tuple.  Used by copy and pickle.'
#         return tuple(self)
#
#     song_name = _property(_itemgetter(0), doc='Alias for field number 0')
#
#     album_name = _property(_itemgetter(1), doc='Alias for field number 1')
#
#     artist_name = _property(_itemgetter(2), doc='Alias for field number 2')
#
#     timestamp = _property(_itemgetter(3), doc='Alias for field number 3')

# %%
example = Listen("Defector", "Drones", "Muse", 1)

# %%
example.song_name
# Out:
# 'Defector'
